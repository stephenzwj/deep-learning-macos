# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/tensorflow-install-mac-metal-jul-2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Manual Python Setup**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Software Installation (Mac on Apple Metal M1)
# This class is technically oriented.  A successful student needs to be able to compile and execute Python code that makes use of TensorFlow for deep learning. There are two options for you to accomplish this:
#
# * Install Python, TensorFlow, and some IDE (Jupyter, TensorFlow, and others)
# * Use Google CoLab in the cloud
#
# ## Installing Python and TensorFlow
#
# Is your Mac Intel or Apple Metal (ARM)? The newer Mac ARM M1/M2/M3-based machines have considerably better deep learning support than their older Intel-based counterparts. Mac has not supported NVIDIA GPUs since 2016; however, the new M1/M2 chips offer similar capabilities that will allow you to run most of the code in this course.  You can run any code not supported by the Apple M1 chip through Google CoLab, a free GPU-based Python environment.
#
# If you are running an older Intel Mac, there still are some options.  Refer to my [Intel Mac installation guide](tensorflow-install-mac-jan-2021.ipynb).
#
# With the introduction of the Apple silicone chip, Apple introduced a system on a chip.  The new Mac M1 contains CPU, GPU, and deep learning hardware support, all on a single chip. The Mac M1 can run software created for the older Intel Mac's using an emulation layer called [Rosetta](https://en.wikipedia.org/wiki/Rosetta_(software)).
#
# ## Install Miniconda
#
# It is possible to install and run Python/TensorFlow entirely from your Mac, without the need for Google CoLab. Running TensorFlow locally does require some software configuration and installation. If you are not confortable with software installation, just use Google CoLab. These instructions show you how to install TensorFlow for both CPU and GPU. Many of the examples in this class will achieve considerable performance improvement from a GPU.
#
# The first step is to install Python 3.9. As of August 2022, this is the latest version of Python 3. I recommend using the Miniconda (Anaconda) release of Python, as it already includes many of the data science related packages that are needed by this class. Anaconda directly supports Windows, Mac, and Linux. Miniconda is the minimal set of features from the extensive Anaconda Python distribution. Download Miniconda from the following URL:
#
# * [Miniconda](https://docs.conda.io/en/latest/miniconda.html)
#
# Next, you should install the xcode-select command-line utilities.  Use the following command to install:
#
# ```
# xcode-select --install
# ```
#
# If the above command gives an error, you should install XCode from the App Store.
#
#
# ## Install Jupyter and Create Environment
#
# Next, lets install Jupyter, which is the editor you will use in this course.
#
# ```
# conda install -y jupyter
# ```
#
# We will actually launch Jupyter later.
#
# First, we deactivate the base environment.
#
# ```
# conda deactivate
# ```
#
# Next, we will install the Apple Silicon [tensorflow-apple-metal-conda.yml](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/tensorflow-apple-metal-conda.yml) file that I provide. Run the following command from the same directory that contains **tensorflow-apple-metal-conda.yml**.
#
# ```
# conda env create -f tensorflow-apple-metal-conda.yml -n tensorflow
# ```
#
# # Activating New Environment
#
# To enter this environment, you must use the following command:
#
# ```
# conda activate tensorflow
# ```
#
# ## Register your Environment
#
# The following command registers your **tensorflow** environment. Again, make sure you "conda activate" your new **tensorflow** environment.
#
# ```
# python -m ipykernel install --user --name tensorflow --display-name "Python 3.9 (tensorflow)"
# ```
#
# ## Testing your Environment
#
# You can now start Jupyter notebook.  Use the following command.
#
# ```
# jupyter notebook
# ```
#
# You can now run the following code to check that you have the versions expected.

# %%
# !conda uninstall -y tensorflow-deps
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/wenjie.zhang/opt/anaconda3
#
#   removed specs:
#     - tensorflow-deps
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-package-handling-2.0.2|   py39hca03da5_0         269 KB
#     conda-package-streaming-0.7.0|   py39hca03da5_0          27 KB
#     huggingface_hub-0.10.1     |   py39hca03da5_0         210 KB
#     sacremoses-0.0.43          |     pyhd3eb1b0_0         284 KB
#     zstandard-0.18.0           |   py39h1a28f6b_0         348 KB
#     ------------------------------------------------------------
#                                            Total:         1.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   conda-package-str~ pkgs/main/osx-arm64::conda-package-streaming-0.7.0-py39hca03da5_0
#   zstandard          pkgs/main/osx-arm64::zstandard-0.18.0-py39h1a28f6b_0
#
# The following packages will be REMOVED:
#
#   grpcio-1.42.0-py39h95c9599_0
#   tensorflow-deps-2.8.0-0
#
# The following packages will be UPDATED:
#
#   conda-package-han~                   1.9.0-py39h1a28f6b_1 --> 2.0.2-py39hca03da5_0
#   sacremoses            huggingface::sacremoses-master-py_0 --> pkgs/main::sacremoses-0.0.43-pyhd3eb1b0_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   huggingface_hub    huggingface/noarch::huggingface_hub-0~ --> pkgs/main/osx-arm64::huggingface_hub-0.10.1-py39hca03da5_0
#
#
#
# Downloading and Extracting Packages
# conda-package-stream | 27 KB     |                                       |   0%
# conda-package-handli | 269 KB    |                                       |   0%
#
# sacremoses-0.0.43    | 284 KB    |                                       |   0%
#
#
# zstandard-0.18.0     | 348 KB    |                                       |   0%
#
#
#
# huggingface_hub-0.10 | 210 KB    |                                       |   0%
#
#
# conda-package-stream | 27 KB     | ##################################### | 100%
# conda-package-handli | 269 KB    | ##################################### | 100%
# conda-package-handli | 269 KB    | ##################################### | 100%
#
#
# zstandard-0.18.0     | 348 KB    | ##################################### | 100%
#
# sacremoses-0.0.43    | 284 KB    | ##                                    |   6%
#
#
#
# huggingface_hub-0.10 | 210 KB    | ##8                                   |   8%
#
# sacremoses-0.0.43    | 284 KB    | ##################################### | 100%
#
#
#
# huggingface_hub-0.10 | 210 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip uninstall tensorflow-macos tensorflow-metal -y
# Out:
# Found existing installation: tensorflow-macos 2.11.0
# Uninstalling tensorflow-macos-2.11.0:
#   Successfully uninstalled tensorflow-macos-2.11.0
# Found existing installation: tensorflow-metal 0.7.0
# Uninstalling tensorflow-metal-0.7.0:
#   Successfully uninstalled tensorflow-metal-0.7.0

# %%
# !conda install -c apple tensorflow-deps -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/wenjie.zhang/opt/anaconda3
#
#   added / updated specs:
#     - tensorflow-deps
#
#
# The following NEW packages will be INSTALLED:
#
#   grpcio             pkgs/main/osx-arm64::grpcio-1.42.0-py39h95c9599_0
#   tensorflow-deps    apple/osx-arm64::tensorflow-deps-2.8.0-0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install tensorflow-macos -U
# Out:
# Collecting tensorflow-macos
#   Using cached tensorflow_macos-2.11.0-cp39-cp39-macosx_12_0_arm64.whl (215.6 MB)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (0.2.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (3.19.4)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (1.6.3)
# Requirement already satisfied: numpy>=1.20 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (1.23.2)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (23.1.4)
# Requirement already satisfied: setuptools in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (1.46.3)
# Requirement already satisfied: h5py>=2.9.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (4.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (0.4.0)
# Requirement already satisfied: packaging in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (22.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (2.1.1)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (2.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (14.0.6)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (2.11.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (1.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-macos) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow-macos) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.2.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (2.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow-macos) (0.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-macos) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-macos) (5.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-macos) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-macos) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-macos) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-macos) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-macos) (3.2.2)
# Installing collected packages: tensorflow-macos
# Successfully installed tensorflow-macos-2.11.0

# %%
# !pip install tensorflow-metal -U
# Out:
# Collecting tensorflow-metal
#   Using cached tensorflow_metal-0.7.0-cp39-cp39-macosx_12_0_arm64.whl (1.4 MB)
# Requirement already satisfied: wheel~=0.35 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-metal) (0.38.4)
# Requirement already satisfied: six>=1.15.0 in /Users/wenjie.zhang/opt/anaconda3/envs/dl/lib/python3.9/site-packages (from tensorflow-metal) (1.15.0)
# Installing collected packages: tensorflow-metal
# Successfully installed tensorflow-metal-0.7.0

# %%
# What version of Python do you have?
import sys

import tensorflow.keras
import pandas as pd
import sklearn as sk
import tensorflow as tf
import platform

print(f"Python Platform: {platform.platform()}")
print(f"Tensor Flow Version: {tf.__version__}")
print(f"Keras Version: {tensorflow.keras.__version__}")
print()
print(f"Python {sys.version}")
print(f"Pandas {pd.__version__}")
print(f"Scikit-Learn {sk.__version__}")
gpu = len(tf.config.list_physical_devices('GPU'))>0
print("GPU is", "available" if gpu else "NOT AVAILABLE")
# Out:
# Python Platform: macOS-13.0.1-arm64-arm-64bit
# Tensor Flow Version: 2.11.0
# Keras Version: 2.11.0
#
# Python 3.9.15 | packaged by conda-forge | (main, Nov 22 2022, 08:48:25)
# [Clang 14.0.6 ]
# Pandas 1.5.2
# Scikit-Learn 1.2.0
# GPU is available

# %%
import torch
has_gpu = torch.cuda.is_available()
has_mps = getattr(torch, "has_mps", False)
device = "mps" if has_mps else "gpu" if has_gpu else "cpu"
print(f"device: {device}")
# Out:
# device: mps

# %%
# !conda install -c huggingface transformers -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/wenjie.zhang/opt/anaconda3
#
#   added / updated specs:
#     - transformers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.11.1              |   py39hca03da5_4         929 KB
#     huggingface_hub-0.11.1     |             py_0         178 KB  huggingface
#     importlib_metadata-4.11.3  |       hd3eb1b0_0          12 KB
#     protobuf-3.20.1            |   py39hc377ac9_0         279 KB
#     ruamel.yaml-0.17.21        |   py39h1a28f6b_0         178 KB
#     ruamel.yaml.clib-0.2.6     |   py39h1a28f6b_1         116 KB
#     sacremoses-master          |             py_0         404 KB  huggingface
#     tokenizers-0.11.4          |   py39h5c5695e_1         2.5 MB
#     transformers-4.25.1        |             py_0         2.8 MB  huggingface
#     ------------------------------------------------------------
#                                            Total:         7.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   huggingface_hub    huggingface/noarch::huggingface_hub-0.11.1-py_0 None
#   importlib_metadata pkgs/main/noarch::importlib_metadata-4.11.3-hd3eb1b0_0 None
#   libprotobuf        pkgs/main/osx-arm64::libprotobuf-3.20.1-h98b2900_0 None
#   protobuf           pkgs/main/osx-arm64::protobuf-3.20.1-py39hc377ac9_0 None
#   ruamel.yaml        pkgs/main/osx-arm64::ruamel.yaml-0.17.21-py39h1a28f6b_0 None
#   ruamel.yaml.clib   pkgs/main/osx-arm64::ruamel.yaml.clib-0.2.6-py39h1a28f6b_1 None
#   sacremoses         huggingface/noarch::sacremoses-master-py_0 None
#   tokenizers         pkgs/main/osx-arm64::tokenizers-0.11.4-py39h5c5695e_1 None
#   transformers       huggingface/noarch::transformers-4.25.1-py_0 None
#
# The following packages will be UPDATED:
#
#   conda                               22.9.0-py39hca03da5_0 --> 22.11.1-py39hca03da5_4 None
#
#
#
# Downloading and Extracting Packages
# conda-22.11.1        | 929 KB    | ##################################### | 100%
# protobuf-3.20.1      | 279 KB    | ##################################### | 100%
# sacremoses-master    | 404 KB    | ##################################### | 100%
# transformers-4.25.1  | 2.8 MB    | ##################################### | 100%
# ruamel.yaml-0.17.21  | 178 KB    | ##################################### | 100%
# huggingface_hub-0.11 | 178 KB    | ##################################### | 100%
# ruamel.yaml.clib-0.2 | 116 KB    | ##################################### | 100%
# tokenizers-0.11.4    | 2.5 MB    | ##################################### | 100%
# importlib_metadata-4 | 12 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done

# %%
# old version
# !pip install transformers==3.0.2 xlrd==1.2.0 openpyxl==3.0.9 swifter==1.1.2 PyArrow==1.0.1
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/wenjie.zhang/opt/anaconda3
#
#   added / updated specs:
#     - transformers
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.11.1              |   py39hca03da5_4         929 KB
#     huggingface_hub-0.10.1     |   py39hca03da5_0         210 KB
#     ninja-1.10.2               |       hca03da5_5           9 KB
#     ninja-base-1.10.2          |       h525c30c_5         108 KB
#     pytorch-1.10.2             |cpu_py39h23cb94c_0        30.6 MB
#     ruamel.yaml-0.17.21        |   py39h1a28f6b_0         178 KB
#     ruamel.yaml.clib-0.2.6     |   py39h1a28f6b_1         116 KB
#     tokenizers-0.11.4          |   py39h5c5695e_1         2.5 MB
#     transformers-4.24.0        |   py39hca03da5_0         4.7 MB
#     ------------------------------------------------------------
#                                            Total:        39.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   huggingface_hub    pkgs/main/osx-arm64::huggingface_hub-0.10.1-py39hca03da5_0 None
#   ninja              pkgs/main/osx-arm64::ninja-1.10.2-hca03da5_5 None
#   ninja-base         pkgs/main/osx-arm64::ninja-base-1.10.2-h525c30c_5 None
#   pytorch            pkgs/main/osx-arm64::pytorch-1.10.2-cpu_py39h23cb94c_0 None
#   ruamel.yaml        pkgs/main/osx-arm64::ruamel.yaml-0.17.21-py39h1a28f6b_0 None
#   ruamel.yaml.clib   pkgs/main/osx-arm64::ruamel.yaml.clib-0.2.6-py39h1a28f6b_1 None
#   tokenizers         pkgs/main/osx-arm64::tokenizers-0.11.4-py39h5c5695e_1 None
#   transformers       pkgs/main/osx-arm64::transformers-4.24.0-py39hca03da5_0 None
#
# The following packages will be UPDATED:
#
#   conda                               22.9.0-py39hca03da5_0 --> 22.11.1-py39hca03da5_4 None
#
#
# Proceed ([y]/n)? ^C
#
# CondaSystemExit:
# Operation aborted.  Exiting.

# %%
import transformers
# from transformers import pipeline
# model = pipeline('feature-extraction')
tokenizer = transformers.BertTokenizer.from_pretrained( "bert-base-uncased", do_lower_case=True
        )
model = transformers.TFBertModel.from_pretrained("bert-base-uncased")#"bert-base-uncased")
model.trainable = False
# Out:
# Downloading:   0%|          | 0.00/536M [00:00<?, ?B/s]
# 2022-12-24 17:18:30.208670: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-12-24 17:18:30.209692: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Metal device set to: Apple M1 Pro
#
# systemMemory: 32.00 GB
# maxCacheSize: 10.67 GB
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
! pip list
# Out:
# Package                  Version
# ------------------------ --------------------
# absl-py                  1.3.0
# addict                   2.4.0
# anyio                    3.6.2
# appnope                  0.1.3
# argon2-cffi              21.3.0
# argon2-cffi-bindings     21.2.0
# arrow                    1.2.3
# asttokens                2.0.8
# attrs                    22.1.0
# Babel                    2.11.0
# backcall                 0.2.0
# beautifulsoup4           4.11.1
# bleach                   5.0.1
# cachetools               5.2.0
# certifi                  2022.12.7
# cffi                     1.15.1
# charset-normalizer       2.1.1
# click                    8.1.3
# colorama                 0.4.6
# commonmark               0.9.1
# contourpy                1.0.6
# cryptography             38.0.4
# cycler                   0.11.0
# Cython                   0.29.32
# debugpy                  1.6.3
# decorator                5.1.1
# defusedxml               0.7.1
# entrypoints              0.4
# executing                1.0.0
# fastjsonschema           2.16.2
# filelock                 3.8.2
# fonttools                4.38.0
# fqdn                     1.5.1
# google-auth              2.15.0
# google-auth-oauthlib     0.4.6
# grpcio                   1.51.1
# huggingface-hub          0.11.1
# idna                     3.4
# ipykernel                6.15.3
# ipython                  8.5.0
# ipython-genutils         0.2.0
# ipywidgets               8.0.2
# isoduration              20.11.0
# jedi                     0.18.1
# Jinja2                   3.1.2
# json5                    0.9.10
# jsonpointer              2.3
# jsonschema               4.16.0
# jupyter                  1.0.0
# jupyter_client           7.4.8
# jupyter-console          6.4.4
# jupyter_core             5.1.0
# jupyter-events           0.5.0
# jupyter_server           2.0.1
# jupyter_server_terminals 0.4.2
# jupyterlab               3.5.1
# jupyterlab-pygments      0.2.2
# jupyterlab_server        2.16.5
# jupyterlab-widgets       3.0.3
# kiwisolver               1.4.4
# lxml                     4.9.1
# Markdown                 3.4.1
# MarkupSafe               2.1.1
# matplotlib               3.6.2
# matplotlib-inline        0.1.6
# mistune                  2.0.4
# mmcv-full                1.7.0
# mmdet                    2.26.0
# model-index              0.1.11
# nbclassic                0.4.8
# nbclient                 0.6.8
# nbconvert                7.0.0
# nbformat                 5.6.0
# nest-asyncio             1.5.5
# notebook                 6.4.12
# notebook_shim            0.2.2
# numpy                    1.24.0
# oauthlib                 3.2.2
# opencv-python            4.6.0.66
# openmim                  0.3.3
# ordered-set              4.1.0
# packaging                21.3
# pandas                   1.5.2
# pandocfilters            1.5.0
# parso                    0.8.3
# pexpect                  4.8.0
# pickleshare              0.7.5
# Pillow                   9.3.0
# pip                      22.3.1
# platformdirs             2.6.0
# ply                      3.11
# prometheus-client        0.14.1
# prompt-toolkit           3.0.31
# protobuf                 3.20.3
# psutil                   5.9.2
# ptyprocess               0.7.0
# pure-eval                0.2.2
# pyasn1                   0.4.8
# pyasn1-modules           0.2.8
# pycocotools              2.0.6
# pycparser                2.21
# Pygments                 2.13.0
# pyparsing                3.0.9
# PyQt-builder             1.14.0
# PyQt6                    6.4.0
# PyQt6-Qt6                6.4.1
# PyQt6-sip                13.4.0
# pyrsistent               0.18.1
# PySide6                  6.4.1
# PySide6-Addons           6.4.1
# PySide6-Essentials       6.4.1
# python-dateutil          2.8.2
# python-json-logger       2.0.4
# pytz                     2022.6
# PyYAML                   6.0
# pyzmq                    24.0.1
# qtconsole                5.3.2
# QtPy                     2.2.0
# regex                    2022.10.31
# requests                 2.28.1
# requests-oauthlib        1.3.1
# rfc3339-validator        0.1.4
# rfc3986-validator        0.1.1
# rich                     12.6.0
# rsa                      4.9
# scipy                    1.9.3
# seaborn                  0.12.1
# semantic-version         2.10.0
# Send2Trash               1.8.0
# setuptools               65.4.1
# setuptools-rust          1.5.2
# shiboken6                6.4.1
# sip                      6.7.5
# six                      1.16.0
# sniffio                  1.3.0
# soupsieve                2.3.2.post1
# stack-data               0.5.0
# tabulate                 0.9.0
# tensorboard              2.11.0
# tensorboard-data-server  0.6.1
# tensorboard-plugin-wit   1.8.1
# terminado                0.15.0
# terminaltables           3.1.10
# thop                     0.1.1.post2209072238
# tinycss2                 1.1.1
# tokenizers               0.13.2
# toml                     0.10.2
# tomli                    2.0.1
# torch                    1.13.0
# torchvision              0.14.0
# tornado                  6.2
# tqdm                     4.64.1
# traitlets                5.7.0
# transformers             4.25.1
# typing_extensions        4.4.0
# uri-template             1.2.0
# urllib3                  1.26.13
# wcwidth                  0.2.5
# webcolors                1.12
# webencodings             0.5.1
# websocket-client         1.4.2
# Werkzeug                 2.2.2
# wheel                    0.37.1
# widgetsnbextension       4.0.3
# yapf                     0.32.0
